# %%
# !pip install Finance-DataReader

import FinanceDataReader as fdr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Requirement already satisfied: Finance-DataReader in c:\users\cha08\anaconda3\lib\site-packages (0.9.96)
# Requirement already satisfied: beautifulsoup4 in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (4.12.3)
# Requirement already satisfied: lxml in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (5.2.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (2.2.2)
# Requirement already satisfied: plotly in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (5.24.1)
# Requirement already satisfied: requests-file in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (1.5.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\cha08\anaconda3\lib\site-packages (from Finance-DataReader) (4.66.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\cha08\anaconda3\lib\site-packages (from pandas>=1.1.0->Finance-DataReader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cha08\anaconda3\lib\site-packages (from pandas>=1.1.0->Finance-DataReader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cha08\anaconda3\lib\site-packages (from pandas>=1.1.0->Finance-DataReader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cha08\anaconda3\lib\site-packages (from pandas>=1.1.0->Finance-DataReader) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\cha08\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->Finance-DataReader) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cha08\anaconda3\lib\site-packages (from requests>=2.3.0->Finance-DataReader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cha08\anaconda3\lib\site-packages (from requests>=2.3.0->Finance-DataReader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cha08\anaconda3\lib\site-packages (from requests>=2.3.0->Finance-DataReader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cha08\anaconda3\lib\site-packages (from requests>=2.3.0->Finance-DataReader) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cha08\anaconda3\lib\site-packages (from beautifulsoup4->Finance-DataReader) (2.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\cha08\anaconda3\lib\site-packages (from plotly->Finance-DataReader) (8.2.3)
# Requirement already satisfied: packaging in c:\users\cha08\anaconda3\lib\site-packages (from plotly->Finance-DataReader) (24.1)
# Requirement already satisfied: colorama in c:\users\cha08\anaconda3\lib\site-packages (from tqdm->Finance-DataReader) (0.4.6)

# %%
# CSV 파일 경로
file_path = r"C:\Gachon\3-1\인공지능개론\AAME.csv"

# CSV 파일 불러오기
df = pd.read_csv(file_path)

# Open 열만 추출
open_prices = df['Open'].values.reshape(-1, 1)

# 결과 출력
print(open_prices)
# Out:
# [[0.       ]
#  [0.       ]
#  [0.       ]
#  ...
#  [2.25     ]
#  [2.1099999]
#  [2.1099999]]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(open_prices)

TEST_SIZE =200
train_data = scaled[:-TEST_SIZE]
test_data =scaled[-TEST_SIZE:]

# %%
def make_sample(data,window):
    train=[]
    target=[]
    for i in range(len(data)-window):
        train.append(data[i:i+window])
        target.append(data[i+window])
    return np.array(train),np.array(target)

X_train, y_train = make_sample(train_data,30)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model = Sequential()
model.add(LSTM(16,
               input_shape=(X_train.shape[1],1),
               activation='tanh',
               return_sequences=False)
           )
model.add(Dense(1))
# Out:
# C:\Users\cha08\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train, y_train, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0038
# Epoch 2/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0026
# Epoch 3/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0029
# Epoch 4/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0026
# Epoch 5/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0025
# Epoch 6/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0023
# Epoch 7/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0022
# Epoch 8/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0027
# Epoch 9/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0025
# Epoch 10/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0020
# Epoch 11/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0028
# Epoch 12/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024
# Epoch 13/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0025
# Epoch 14/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0021
# Epoch 15/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0025
# Epoch 16/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0019
# Epoch 17/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0023
# Epoch 18/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 19/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0027
# Epoch 20/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0018
# Epoch 21/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0025
# Epoch 22/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 23/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023
# Epoch 24/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0020
# Epoch 25/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0022
# Epoch 26/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 27/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020
# Epoch 28/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0022
# Epoch 29/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0023
# Epoch 30/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0022
# Epoch 31/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0026
# Epoch 32/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020
# Epoch 33/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0024
# Epoch 34/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0025
# Epoch 35/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0020
# Epoch 36/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0021
# Epoch 37/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0022
# Epoch 38/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0021
# Epoch 39/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024
# Epoch 40/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 41/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0022
# Epoch 42/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024
# Epoch 43/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0021
# Epoch 44/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020
# Epoch 45/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019
# Epoch 46/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0022
# Epoch 47/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0024
# Epoch 48/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0025
# Epoch 49/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0022
# Epoch 50/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0026
# Epoch 51/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0029
# Epoch 52/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0024
# Epoch 53/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0025
# Epoch 54/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0020
# Epoch 55/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019
# Epoch 56/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0022
# Epoch 57/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024
# Epoch 58/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024
# Epoch 59/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0024
# Epoch 60/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0023
# Epoch 61/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0032
# Epoch 62/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0023
# Epoch 63/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0024
# Epoch 64/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019
# Epoch 65/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023
# Epoch 66/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0020
# Epoch 67/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0022
# Epoch 68/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0022
# Epoch 69/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0024
# Epoch 70/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023
# Epoch 71/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0022
# Epoch 72/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0023
# Epoch 73/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0020
# Epoch 74/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020
# Epoch 75/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020
# Epoch 76/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0030
# Epoch 77/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0019
# Epoch 78/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0020
# Epoch 79/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 80/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0019
# Epoch 81/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0021
# Epoch 82/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0018
# Epoch 83/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0020
# Epoch 84/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0021
# Epoch 85/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0021
# Epoch 86/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.0024
# Epoch 87/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.0024
# Epoch 88/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0026
# Epoch 89/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023
# Epoch 90/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0025
# Epoch 91/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0022
# Epoch 92/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0020
# Epoch 93/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0020
# Epoch 94/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0022
# Epoch 95/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023
# Epoch 96/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0024
# Epoch 97/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0018
# Epoch 98/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0017
# Epoch 99/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023
# Epoch 100/100
# 617/617 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0023

# %%
X_test, y_test= make_sample(test_data,30)
pred=model.predict(X_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,9))
plt.plot(y_test, label='stock price')
plt.plot(pred, label='predicted stock price')
plt.legend()
plt.show()
